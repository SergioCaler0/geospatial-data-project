# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
token1 = os.getenv("token1")
token2 = os.getenv("token2")

# %%
url_mother = 'http://api.foursquare.com/v2/venues/explore'

# %%
ps = {"client_id" : token1,
     "client_secret": token2,
     "v": "20180323",
      "ll": "40.726155, -73.995625",
     "query" : "vegan",
      "limit" : 10,
     }

# %%
response = requests.get(url_mother, ps)

# %%
response
# Out:
# <Response [200]>

# %%
decoding_data = response.json().get("response").get("groups")[0].get("items")

# %%
decoding_data
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '569a9926498e55968fcb812d',
#    'name': 'Double Zero',
#    'contact': {},
#    'location': {'address': '65 2nd Ave',
#     'crossStreet': 'at E 4th St',
#     'lat': 40.72610826388715,
#     'lng': -73.98980624666206,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72610826388715,
#       'lng': -73.98980624666206}],
#     'distance': 490,
#     'postalCode': '10003',
#     'cc': 'US',
#     'neighborhood': 'East Village',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['65 2nd Ave (at E 4th St)',
#      'New York, NY 10003',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1717215',
#     'url': 'https://www.seamless.com/menu/double-zero-65-second-avenue-new-york/1717215?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1717215',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-569a9926498e55968fcb812d-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '583cbde018fd2b1949b98e25',
#    'name': 'by CHLOE.',
#    'contact': {},
#    'location': {'address': '240 Lafayette St',
#     'crossStreet': 'btwn Spring & Prince St',
#     'lat': 40.72277,
#     'lng': -73.9972,
#     'labeledLatLngs': [{'label': 'display', 'lat': 40.72277, 'lng': -73.9972}],
#     'distance': 399,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['240 Lafayette St (btwn Spring & Prince St)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1017796',
#     'url': 'https://www.seamless.com/menu/by-chloe-240-lafayette-st-new-york/1017796?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1017796',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-583cbde018fd2b1949b98e25-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '3fd66200f964a520ede91ee3',
#    'name': 'Quantum Leap',
#    'contact': {},
#    'location': {'address': '226 Thompson St',
#     'crossStreet': 'btwn Bleecker & W 3rd St',
#     'lat': 40.729209246692434,
#     'lng': -73.99886686851244,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.729209246692434,
#       'lng': -73.99886686851244}],
#     'distance': 436,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['226 Thompson St (btwn Bleecker & W 3rd St)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '521301',
#     'url': 'https://www.seamless.com/menu/quantum-leap-226-thompson-st-new-york/521301?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=521301',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-3fd66200f964a520ede91ee3-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49fb5a63f964a520396e1fe3',
#    'name': 'Little Atlas',
#    'contact': {},
#    'location': {'address': '6 W 4th St',
#     'crossStreet': 'btw Broadway and Mercer',
#     'lat': 40.72864590951415,
#     'lng': -73.99472251691711,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72864590951415,
#       'lng': -73.99472251691711},
#      {'label': 'entrance', 'lat': 40.728522, 'lng': -73.994635}],
#     'distance': 287,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['6 W 4th St (btw Broadway and Mercer)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-49fb5a63f964a520396e1fe3-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50770d04e4b0eca51a5714f7',
#    'name': "The Butcher's Daughter",
#    'contact': {},
#    'location': {'address': '19 Kenmare St',
#     'crossStreet': 'at Elizabeth St',
#     'lat': 40.720592723672716,
#     'lng': -73.99490554160472,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.720592723672716,
#       'lng': -73.99490554160472}],
#     'distance': 622,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['19 Kenmare St (at Elizabeth St)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1259358',
#     'url': 'https://www.seamless.com/menu/the-butchers-daughter-19-kenmare-st-new-york/1259358?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1259358',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '81106180'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-50770d04e4b0eca51a5714f7-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b4f6600f964a520cf0427e3',
#    'name': 'Red Bamboo',
#    'contact': {},
#    'location': {'address': '140 W 4th St',
#     'crossStreet': 'btwn 6th Ave & MacDougal St',
#     'lat': 40.731319,
#     'lng': -74.000359,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.731319,
#       'lng': -74.000359},
#      {'label': 'entrance', 'lat': 40.731295, 'lng': -74.000317}],
#     'distance': 699,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['140 W 4th St (btwn 6th Ave & MacDougal St)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '2185145',
#     'url': 'https://www.seamless.com/menu/red-bamboo-140-west-4th-street-new-york/2185145?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2185145',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-4b4f6600f964a520cf0427e3-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a75edcff964a520b3e11fe3',
#    'name': 'Wild Ginger Vegetarian Kitchen',
#    'contact': {},
#    'location': {'address': '380 Broome St',
#     'crossStreet': 'at Mulberry St.',
#     'lat': 40.7204313711967,
#     'lng': -73.99663971306008,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.7204313711967,
#       'lng': -73.99663971306008},
#      {'label': 'entrance', 'lat': 40.72046, 'lng': -73.99646}],
#     'distance': 642,
#     'postalCode': '10013',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['380 Broome St (at Mulberry St.)',
#      'New York, NY 10013',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '295143',
#     'url': 'https://www.seamless.com/menu/luannes-wild-ginger-all-asian-vegetarian-380-broome-st-new-york/295143?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=295143',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '81957581'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-4a75edcff964a520b3e11fe3-6'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5c4a63b11987ec002cddaece',
#    'name': 'Spicy Moon',
#    'contact': {},
#    'location': {'address': '328 E 6th St',
#     'crossStreet': 'btwn 1st & 2nd Ave',
#     'lat': 40.72675410362935,
#     'lng': -73.98709466079313,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72675410362935,
#       'lng': -73.98709466079313}],
#     'distance': 722,
#     'postalCode': '10003',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['328 E 6th St (btwn 1st & 2nd Ave)',
#      'New York, NY 10003',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-5c4a63b11987ec002cddaece-7'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5138b615e4b0cdf575993654',
#    'name': 'Peacefood Café',
#    'contact': {},
#    'location': {'address': '41 E 11th St',
#     'crossStreet': 'at University Pl',
#     'lat': 40.733191059945106,
#     'lng': -73.99295917113982,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.733191059945106,
#       'lng': -73.99295917113982}],
#     'distance': 814,
#     'postalCode': '10003',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['41 E 11th St (at University Pl)',
#      'New York, NY 10003',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '320028',
#     'url': 'https://www.seamless.com/menu/peacefood-cafe-downtown-41-e-11th-st-new-york/320028?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=320028',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '95717606'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-5138b615e4b0cdf575993654-8'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f2bfc7a00390f03ad69ca84',
#    'name': 'Juice Press',
#    'contact': {},
#    'location': {'address': '250 Mott St',
#     'crossStreet': 'btwn Houston & Prince',
#     'lat': 40.723438932887795,
#     'lng': -73.99487685126599,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.723438932887795,
#       'lng': -73.99487685126599}],
#     'distance': 308,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['250 Mott St (btwn Houston & Prince)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4f2bfc7a00390f03ad69ca84-9'}]

# %%
vegan = decoding_data

# %%
vegan
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '569a9926498e55968fcb812d',
#    'name': 'Double Zero',
#    'contact': {},
#    'location': {'address': '65 2nd Ave',
#     'crossStreet': 'at E 4th St',
#     'lat': 40.72610826388715,
#     'lng': -73.98980624666206,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72610826388715,
#       'lng': -73.98980624666206}],
#     'distance': 490,
#     'postalCode': '10003',
#     'cc': 'US',
#     'neighborhood': 'East Village',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['65 2nd Ave (at E 4th St)',
#      'New York, NY 10003',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1717215',
#     'url': 'https://www.seamless.com/menu/double-zero-65-second-avenue-new-york/1717215?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1717215',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-569a9926498e55968fcb812d-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '583cbde018fd2b1949b98e25',
#    'name': 'by CHLOE.',
#    'contact': {},
#    'location': {'address': '240 Lafayette St',
#     'crossStreet': 'btwn Spring & Prince St',
#     'lat': 40.72277,
#     'lng': -73.9972,
#     'labeledLatLngs': [{'label': 'display', 'lat': 40.72277, 'lng': -73.9972}],
#     'distance': 399,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['240 Lafayette St (btwn Spring & Prince St)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1017796',
#     'url': 'https://www.seamless.com/menu/by-chloe-240-lafayette-st-new-york/1017796?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1017796',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-583cbde018fd2b1949b98e25-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '3fd66200f964a520ede91ee3',
#    'name': 'Quantum Leap',
#    'contact': {},
#    'location': {'address': '226 Thompson St',
#     'crossStreet': 'btwn Bleecker & W 3rd St',
#     'lat': 40.729209246692434,
#     'lng': -73.99886686851244,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.729209246692434,
#       'lng': -73.99886686851244}],
#     'distance': 436,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['226 Thompson St (btwn Bleecker & W 3rd St)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '521301',
#     'url': 'https://www.seamless.com/menu/quantum-leap-226-thompson-st-new-york/521301?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=521301',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-3fd66200f964a520ede91ee3-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49fb5a63f964a520396e1fe3',
#    'name': 'Little Atlas',
#    'contact': {},
#    'location': {'address': '6 W 4th St',
#     'crossStreet': 'btw Broadway and Mercer',
#     'lat': 40.72864590951415,
#     'lng': -73.99472251691711,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72864590951415,
#       'lng': -73.99472251691711},
#      {'label': 'entrance', 'lat': 40.728522, 'lng': -73.994635}],
#     'distance': 287,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['6 W 4th St (btw Broadway and Mercer)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-49fb5a63f964a520396e1fe3-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50770d04e4b0eca51a5714f7',
#    'name': "The Butcher's Daughter",
#    'contact': {},
#    'location': {'address': '19 Kenmare St',
#     'crossStreet': 'at Elizabeth St',
#     'lat': 40.720592723672716,
#     'lng': -73.99490554160472,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.720592723672716,
#       'lng': -73.99490554160472}],
#     'distance': 622,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['19 Kenmare St (at Elizabeth St)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1259358',
#     'url': 'https://www.seamless.com/menu/the-butchers-daughter-19-kenmare-st-new-york/1259358?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1259358',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '81106180'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-50770d04e4b0eca51a5714f7-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b4f6600f964a520cf0427e3',
#    'name': 'Red Bamboo',
#    'contact': {},
#    'location': {'address': '140 W 4th St',
#     'crossStreet': 'btwn 6th Ave & MacDougal St',
#     'lat': 40.731319,
#     'lng': -74.000359,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.731319,
#       'lng': -74.000359},
#      {'label': 'entrance', 'lat': 40.731295, 'lng': -74.000317}],
#     'distance': 699,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['140 W 4th St (btwn 6th Ave & MacDougal St)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '2185145',
#     'url': 'https://www.seamless.com/menu/red-bamboo-140-west-4th-street-new-york/2185145?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2185145',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-4b4f6600f964a520cf0427e3-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a75edcff964a520b3e11fe3',
#    'name': 'Wild Ginger Vegetarian Kitchen',
#    'contact': {},
#    'location': {'address': '380 Broome St',
#     'crossStreet': 'at Mulberry St.',
#     'lat': 40.7204313711967,
#     'lng': -73.99663971306008,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.7204313711967,
#       'lng': -73.99663971306008},
#      {'label': 'entrance', 'lat': 40.72046, 'lng': -73.99646}],
#     'distance': 642,
#     'postalCode': '10013',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['380 Broome St (at Mulberry St.)',
#      'New York, NY 10013',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '295143',
#     'url': 'https://www.seamless.com/menu/luannes-wild-ginger-all-asian-vegetarian-380-broome-st-new-york/295143?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=295143',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '81957581'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-4a75edcff964a520b3e11fe3-6'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5c4a63b11987ec002cddaece',
#    'name': 'Spicy Moon',
#    'contact': {},
#    'location': {'address': '328 E 6th St',
#     'crossStreet': 'btwn 1st & 2nd Ave',
#     'lat': 40.72675410362935,
#     'lng': -73.98709466079313,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72675410362935,
#       'lng': -73.98709466079313}],
#     'distance': 722,
#     'postalCode': '10003',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['328 E 6th St (btwn 1st & 2nd Ave)',
#      'New York, NY 10003',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-5c4a63b11987ec002cddaece-7'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5138b615e4b0cdf575993654',
#    'name': 'Peacefood Café',
#    'contact': {},
#    'location': {'address': '41 E 11th St',
#     'crossStreet': 'at University Pl',
#     'lat': 40.733191059945106,
#     'lng': -73.99295917113982,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.733191059945106,
#       'lng': -73.99295917113982}],
#     'distance': 814,
#     'postalCode': '10003',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['41 E 11th St (at University Pl)',
#      'New York, NY 10003',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '320028',
#     'url': 'https://www.seamless.com/menu/peacefood-cafe-downtown-41-e-11th-st-new-york/320028?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=320028',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '95717606'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-5138b615e4b0cdf575993654-8'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f2bfc7a00390f03ad69ca84',
#    'name': 'Juice Press',
#    'contact': {},
#    'location': {'address': '250 Mott St',
#     'crossStreet': 'btwn Houston & Prince',
#     'lat': 40.723438932887795,
#     'lng': -73.99487685126599,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.723438932887795,
#       'lng': -73.99487685126599}],
#     'distance': 308,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['250 Mott St (btwn Houston & Prince)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4f2bfc7a00390f03ad69ca84-9'}]

# %%
from functools import reduce
import operator

# %%
mapa_nombre = ["venue","name"]
ubicacion = ["venue", "location", "city"]
latitud = ["venue", "location","lat"]
longitud = ["venue","location","lng"]

# %%
def getFromDict(diccionario,mapa):
    return reduce(operator.getitem,mapa,diccionario)

# %%
lista_vegan = []
for diccionario in vegan:
    paralista = {}
    paralista["name"] = getFromDict(diccionario,mapa_nombre)
    paralista["city"] = getFromDict(diccionario, ubicacion)
    paralista["latitud"] = getFromDict(diccionario,latitud)
    paralista["longitud"] = getFromDict(diccionario,longitud)
    lista_vegan.append(paralista)

# %%
dataframefinalvegan = pd.DataFrame(lista_vegan)

dataframefinalvegan.head(2)
# Out:
#           name      city    latitud   longitud
# 0  Double Zero  New York  40.726108 -73.989806
# 1    by CHLOE.  New York  40.722770 -73.997200

# %%
data_vegan=dataframefinalvegan.assign(etiqueta= 'vegan')

# %%
data_vegan.head(2)
# Out:
#           name      city    latitud   longitud etiqueta
# 0  Double Zero  New York  40.726108 -73.989806    vegan
# 1    by CHLOE.  New York  40.722770 -73.997200    vegan

# %%
data_vegan.to_csv('Data_vegan.csv')
